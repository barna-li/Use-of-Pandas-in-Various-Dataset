# %% [markdown]
# ## 1.Read this dataset in pandas

# %%
import mysql.connector
from mysql.connector import Error
from sqlalchemy import create_engine
import pandas as pd

# %%
df = pd.read_csv('/Users/barnalikkapradhan/Downloads/FitBit.csv')
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   ActivityDate              457 non-null    object
#  2   TotalSteps                457 non-null    int64
#  3   TotalDistance             457 non-null    float64
#  4   TrackerDistance           457 non-null    float64
#  5   LoggedActivitiesDistance  457 non-null    float64
#  6   VeryActiveDistance        457 non-null    float64
#  7   ModeratelyActiveDistance  457 non-null    float64
#  8   LightActiveDistance       457 non-null    float64
#  9   SedentaryActiveDistance   457 non-null    float64
#  10  VeryActiveMinutes         457 non-null    int64
#  11  FairlyActiveMinutes       457 non-null    int64
#  12  LightlyActiveMinutes      457 non-null    int64
# ...

# %% [markdown]
# ## 2. Load the data in bulk in you mysql via Python

# %%
engine = create_engine('mysql+mysqlconnector://root:Boomclap4!@localhost:3306/TESTU',echo=False)

# %%
df.to_sql('FITBIT', con= engine, if_exists='append', index = False)

# %% [markdown]
# ## 3. Convert all the dates available in dataset to timestamp format in pandas

# %%
df['ActivityDate'] = df['ActivityDate'].apply(lambda x: pd.Timestamp(x).strftime("%Y-%m-%d %I:%M %p"))
df
# Out:
#              Id         ActivityDate  TotalSteps  TotalDistance  \
# 0    1503960366  2016-03-25 12:00 AM       11004       7.110000
# 1    1503960366  2016-03-26 12:00 AM       17609      11.550000
# 2    1503960366  2016-03-27 12:00 AM       12736       8.530000
# 3    1503960366  2016-03-28 12:00 AM       13231       8.930000
# 4    1503960366  2016-03-29 12:00 AM       12041       7.850000
# ..          ...                  ...         ...            ...
# 452  8877689391  2016-04-08 12:00 AM       23014      20.389999
# 453  8877689391  2016-04-09 12:00 AM       16470       8.070000
# 454  8877689391  2016-04-10 12:00 AM       28497      27.530001
# 455  8877689391  2016-04-11 12:00 AM       10622       8.060000
# 456  8877689391  2016-04-12 12:00 AM        2350       1.780000
#
#      TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 0           7.110000                       0.0                2.57
# ...

# %% [markdown]
# ## 4. Find out in this data that how many unique id's we have

# %%
n = len(pd.unique(df['Id']))
print("No of unique Id's :",n)
# Out:
# No of unique Id's : 35

# %% [markdown]
# ## 5.  Which id is one of the active id that you have in whole dataset

# %%
#Here we check the most active id according tot he total steps the person has completed in a day.
df[df.TotalSteps == df.TotalSteps.max()]
# Out:
#              Id         ActivityDate  TotalSteps  TotalDistance  \
# 454  8877689391  2016-04-10 12:00 AM       28497      27.530001
#
#      TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 454        27.530001                       0.0               21.92
#
#      ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# 454                      1.12                 4.46                      0.0
#
#      VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# 454                128                   46                   211
#
#      SedentaryMinutes  Calories
# 454              1055      4526

# %% [markdown]
# ## 6. How many of them have not logged there activity find out in terms of number of ids

# %%
d=df['Id'][df["LoggedActivitiesDistance"] < 1]
d.value_counts()
# Out:
# 4057192912    32
# 4020332650    32
# 1503960366    19
# 1624580081    19
# 2347167796    15
# 4702921684    15
# 4445114986    15
# 2320127002    12
# 1844505072    12
# 8792009665    12
# 8253242879    12
# 7086361926    12
# 2026352035    12
# 5553957443    12
# 4558609924    12
# 8877689391    12
# 1927972279    12
# 2022484408    12
# 3977333714    12
# 2873212765    12
# 4319703577    12
# 5577150313    11
# 8053475328    11
# 3372868164    10
# 1644430081    10
# 6117666160    10
# 6290855005    10
# 6962181067    10
# 6775888955     9
# 8583815059     8
# 4388161847     8
# 6391747486     7
# 7007744171     5
# 2891001357     5
# 8378563200     5
# Name: Id, dtype: int64

# %% [markdown]
# ## 7 . Find out who is the laziest person id that we have in dataset

# %%
#Here the lowest Calories burnt along with high sedentary minutes gives us the list of all the laziest persons 
#which is the same for 5 people unique id's.
df[df.Calories == df.Calories.min()]
# Out:
#              Id         ActivityDate  TotalSteps  TotalDistance  \
# 134  2873212765  2016-04-12 12:00 AM           0            0.0
# 240  4319703577  2016-04-09 12:00 AM           0            0.0
# 290  4702921684  2016-04-12 12:00 AM           0            0.0
# 323  6117666160  2016-04-10 12:00 AM           0            0.0
# 412  8253242879  2016-04-12 12:00 AM           0            0.0
#
#      TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 134              0.0                       0.0                 0.0
# 240              0.0                       0.0                 0.0
# 290              0.0                       0.0                 0.0
# 323              0.0                       0.0                 0.0
# 412              0.0                       0.0                 0.0
#
#      ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# 134                       0.0                  0.0                      0.0
# ...

# %% [markdown]
# ## 8. Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset

# %%
Healthy= df[df['Calories'] >= 2500]
Healthy
# Out:
#              Id         ActivityDate  TotalSteps  TotalDistance  \
# 38   1644430081  2016-04-01 12:00 AM        4636       3.410000
# 39   1644430081  2016-04-02 12:00 AM       20237      14.710000
# 40   1644430081  2016-04-03 12:00 AM       12912       9.410000
# 42   1644430081  2016-04-05 12:00 AM        9921       7.210000
# 43   1644430081  2016-04-06 12:00 AM        8046       5.850000
# ..          ...                  ...         ...            ...
# 451  8877689391  2016-04-07 12:00 AM       10910       8.420000
# 452  8877689391  2016-04-08 12:00 AM       23014      20.389999
# 453  8877689391  2016-04-09 12:00 AM       16470       8.070000
# 454  8877689391  2016-04-10 12:00 AM       28497      27.530001
# 455  8877689391  2016-04-11 12:00 AM       10622       8.060000
#
#      TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 38          3.410000                       0.0                0.00
# ...

# %%
n = len(Healthy['Calories'])
print("No.of Healthy people in Dataset :",n)
# Out:
# No.of Healthy people in Dataset : 133

# %% [markdown]
# ## 10. who is the third most active person in this dataset find out those in pandas

# %%
#The person with first and second most total steps completed belongs to one id so segregating it 
#and looking into other unique id thereon we get our third most active person id.
Third_active= df.nlargest(n=8,columns=['TotalSteps'])
Third_active
# Out:
#              Id         ActivityDate  TotalSteps  TotalDistance  \
# 454  8877689391  2016-04-10 12:00 AM       28497      27.530001
# 446  8877689391  2016-04-02 12:00 AM       27572      23.389999
# 391  8053475328  2016-04-03 12:00 AM       25701      20.139999
# 450  8877689391  2016-04-06 12:00 AM       24136      20.910000
# 452  8877689391  2016-04-08 12:00 AM       23014      20.389999
# 448  8877689391  2016-04-04 12:00 AM       20779      18.410000
# 39   1644430081  2016-04-02 12:00 AM       20237      14.710000
# 390  8053475328  2016-04-02 12:00 AM       20188      15.620000
#
#      TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 454        27.530001                       0.0               21.92
# 446        23.389999                       0.0               14.72
# 391        20.139999                       0.0               16.82
# 450        20.910000                       0.0               12.22
# ...

# %%
Third_active.iloc[6:7]
# Out:
#             Id         ActivityDate  TotalSteps  TotalDistance  \
# 39  1644430081  2016-04-02 12:00 AM       20237          14.71
#
#     TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 39            14.71                       0.0                2.57
#
#     ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# 39                       6.4                 5.73                     0.01
#
#     VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# 39                 34                  141                   347
#
#     SedentaryMinutes  Calories
# 39               918      4029

# %% [markdown]
# ## 11. who is the 5th most laziest person avilable in dataset find it out

# %%
fifth_laziest = df.nsmallest(n=5,columns=['Calories'])
fifth_laziest
# Out:
#              Id         ActivityDate  TotalSteps  TotalDistance  \
# 134  2873212765  2016-04-12 12:00 AM           0            0.0
# 240  4319703577  2016-04-09 12:00 AM           0            0.0
# 290  4702921684  2016-04-12 12:00 AM           0            0.0
# 323  6117666160  2016-04-10 12:00 AM           0            0.0
# 412  8253242879  2016-04-12 12:00 AM           0            0.0
#
#      TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 134              0.0                       0.0                 0.0
# 240              0.0                       0.0                 0.0
# 290              0.0                       0.0                 0.0
# 323              0.0                       0.0                 0.0
# 412              0.0                       0.0                 0.0
#
#      ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# 134                       0.0                  0.0                      0.0
# ...

# %%
fifth_laziest.iloc[4:5]
# Out:
#              Id         ActivityDate  TotalSteps  TotalDistance  \
# 412  8253242879  2016-04-12 12:00 AM           0            0.0
#
#      TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 412              0.0                       0.0                 0.0
#
#      ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# 412                       0.0                  0.0                      0.0
#
#      VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# 412                  0                    0                     0
#
#      SedentaryMinutes  Calories
# 412              1440         0

# %% [markdown]
# ## 12. what is a total accumulative calories burnt for a person find out

# %%
df.Calories= df.sum(axis = 1)
df
# Out:
# /var/folders/vr/17bc0vfj6jng59j_txbvmd0r0000gn/T/ipykernel_59213/1298463568.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.Calories= df.sum(axis = 1)
#              Id         ActivityDate  TotalSteps  TotalDistance  \
# 0    1503960366  2016-03-25 12:00 AM       11004       7.110000
# 1    1503960366  2016-03-26 12:00 AM       17609      11.550000
# 2    1503960366  2016-03-27 12:00 AM       12736       8.530000
# 3    1503960366  2016-03-28 12:00 AM       13231       8.930000
# 4    1503960366  2016-03-29 12:00 AM       12041       7.850000
# ..          ...                  ...         ...            ...
# 452  8877689391  2016-04-08 12:00 AM       23014      20.389999
# 453  8877689391  2016-04-09 12:00 AM       16470       8.070000
# 454  8877689391  2016-04-10 12:00 AM       28497      27.530001
# ...
